# %% [markdown]
# # Preprocess all the matches

# %% [markdown]
# #### Libraries

# %%
import pandas as pd
import os
from pathlib import Path
from tqdm import tqdm
from datetime import datetime

# %% [markdown]
# #### Functions

# %%
def load_all_df(folder_path) -> pd.DataFrame:
    folder = Path(folder_path)

    df = pd.DataFrame()
    
    for subdir, dirs, files in os.walk(folder):
        for file in tqdm(sorted(files), total=len(files)-1):
            if file.endswith('.csv'):
                file_path = os.path.join(subdir, file)
                data = pd.read_csv(file_path)
                df = pd.concat([df, data], axis = 0)

    return df

# %%
def clean_df(data):

    tourney_id = data['tourney_id']\
        .astype(str)\
        .rename('tourney_id')
    
    tour_year = data['tourney_id']\
        .astype(str)\
        .str[:4]\
        .rename('tour_year')
    
    tourney_name = data['tourney_name']\
        .astype(str)\
        .rename('tourney_name')
    
    surface = data['surface']\
        .astype(str)\
        .fillna('Unknown')\
        .replace('nan', 'Unknown')\
        .rename('surface')
    
    # draw_size = data['draw_size']\
    #     .fillna(0)\
    #     .replace('nan', 0)\
    #     .astype(int)\
    #     .rename('draw_size')
    
    tourney_level = data["tourney_level"]\
        .astype(str)\
        .rename('tourney_level')
    
    tourney_date = pd.to_datetime(data['tourney_date'], format='%Y%m%d').rename('tourney_date')
    
    match_num = data["match_num"]\
        .astype(int)\
        .rename('match_num')
    
    match_id = (data['tourney_id'].astype(str) + data['match_num'].astype(str))\
        .astype(str)\
        .rename('match_id')

    score = data["score"]\
        .astype(str)\
        .replace('nan', 'Unknown')\
        .rename('score')
    
    best_of = data["best_of"]\
        .astype(int)\
        .rename('best_of')
    
    round = data["round"]\
        .astype(str)\
        .rename('round')

    num_sets = data['score']\
        .apply(lambda x: len(x.split()) if isinstance(x, str) else 0)\
        .rename('num_sets')
    

    winner_id = data['winner_id']\
        .astype(int)\
        .rename('winner_id')
    
    winner_name = data['winner_name']\
        .astype(str)\
        .rename('winner_name')
    
    # winner_rank_points = data['winner_rank_points']\
    #     .astype(int)\
    #     .rename('winner_rank_points')
    
    loser_id = data['loser_id']\
        .astype(int)\
        .rename('loser_id')
    
    loser_name = data['loser_name']\
        .astype(str)\
        .rename('loser_name')
    
    # loser_rank_points = data['loser_rank_points']\
    #     .astype(int)\
    #     .rename('loser_rank_points')
    
    cleaned_df = pd.concat(
        [   
            match_id,
            tour_year,
            tourney_id, 
            tourney_name, 
            surface, 
            # draw_size, 
            tourney_level, 
            tourney_date, 
            match_num, 
            score, 
            best_of, 
            round, 
            num_sets,
            winner_id, 
            winner_name, 
            # winner_rank_points, 
            loser_id, 
            loser_name],
            # loser_rank_points], 
         axis=1)
    
    assert cleaned_df.isna().sum().sum() == 0,\
        f'There are {cleaned_df.isna().sum()} nan values'
    
    return cleaned_df.sort_values('tourney_date').set_index('match_id', drop=False)

# %% [markdown]
# #### Treating data

# %%
dataframe = load_all_df('../data/atp_matches')
wta_dataframe = load_all_df('../data/wta_matches')
# Out:
#   7%|▋         | 4/54 [00:00<00:02, 17.98it/s]
# 55it [00:04, 13.14it/s]
# 57it [00:03, 16.62it/s]

# %%
clean_data = clean_df(dataframe)
clean_wta_data = clean_df(wta_dataframe)

# %%
clean_data.columns
# Out:
# Index(['match_id', 'tour_year', 'tourney_id', 'tourney_name', 'surface',
#        'tourney_level', 'tourney_date', 'match_num', 'score', 'best_of',
#        'round', 'num_sets', 'winner_id', 'winner_name', 'loser_id',
#        'loser_name'],
#       dtype='object')

# %%
clean_wta_data.columns
# Out:
# Index(['match_id', 'tour_year', 'tourney_id', 'tourney_name', 'surface',
#        'tourney_level', 'tourney_date', 'match_num', 'score', 'best_of',
#        'round', 'num_sets', 'winner_id', 'winner_name', 'loser_id',
#        'loser_name'],
#       dtype='object')

# %%
clean_data.isna().sum()
# Out:
# match_id         0
# tour_year        0
# tourney_id       0
# tourney_name     0
# surface          0
# tourney_level    0
# tourney_date     0
# match_num        0
# score            0
# best_of          0
# round            0
# num_sets         0
# winner_id        0
# winner_name      0
# loser_id         0
# loser_name       0
# dtype: int64

# %%
clean_wta_data.isna().sum()
# Out:
# match_id         0
# tour_year        0
# tourney_id       0
# tourney_name     0
# surface          0
# tourney_level    0
# tourney_date     0
# match_num        0
# score            0
# best_of          0
# round            0
# num_sets         0
# winner_id        0
# winner_name      0
# loser_id         0
# loser_name       0
# dtype: int64

# %% [markdown]
# #### Save data to csv

# %%
clean_data.to_csv('../web_data/clean_atp_matches.csv', index=False)
clean_wta_data.to_csv('../web_data/clean_wta_matches.csv', index=False)

# %% [markdown]
# # Players

# %%
players = pd.read_csv('../data/atp_players.csv')
wta_players = pd.read_csv('../data/wta_players.csv')
# Out:
# /var/folders/s3/s4gmfm1j23xg8_5fnbsqlflm0000gp/T/ipykernel_9501/1323896356.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   players = pd.read_csv('../data/atp_players.csv')
# /var/folders/s3/s4gmfm1j23xg8_5fnbsqlflm0000gp/T/ipykernel_9501/1323896356.py:2: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   wta_players = pd.read_csv('../data/wta_players.csv')

# %%
wta_players.isna().sum()
# Out:
# player_id          0
# name_first      4208
# name_last          0
# hand               3
# dob            44242
# ioc             1091
# height         68694
# wikidata_id    66329
# dtype: int64

# %% [markdown]
# No hi ha cap na a player_id però tenim jugadors sense noms ni cognoms...

# %%
players['player_id'].isna().sum()
# Out:
# np.int64(0)

# %%
players[['name_first', 'name_last']].isna().all(axis=1).sum()
# Out:
# np.int64(48)

# %%
def clean_players_df(players):

    # Faig drop na de player_id però no n'hi ha cap. 
    player_id = players['player_id']\
        .dropna()\
        .astype(int)\
        .rename('player_id')

    name_first = players['name_first']\
        .fillna('Desconegut')\
        .replace({'X': 'Desconegut'})\
        .astype(str)\
        .rename('First Name')

    name_last = players['name_last']\
        .fillna('Desconegudez')\
        .replace({'X': 'Desconegudez'})\
        .astype(str)\
        .rename('Last Name')

    hand = players['hand']\
        .fillna('U')\
        .astype(str)\
        .rename('Hand')

    country = players['ioc']\
        .fillna('UNK')\
        .astype(str)\
        .rename('Country')

    height = players['height']\
        .fillna(0)\
        .astype(int)\
        .rename('Height')
    
    wikidata_id = players['wikidata_id']\
        .fillna('NOID')\
        .astype(str)\
        .rename('wikidata_id')

    clean_players = pd.concat(
        [wikidata_id,
        name_first,
        name_last,
        hand,
        country,
        height],
        axis=1
    ).set_index(player_id, drop=False)

    return clean_players

# %%
clean_players = clean_players_df(players)
clean_wta_players = clean_players_df(wta_players)

# %%
clean_players.isna().sum()
# Out:
# wikidata_id    0
# First Name     0
# Last Name      0
# Hand           0
# Country        0
# Height         0
# dtype: int64

# %%
clean_wta_players.isna().sum()
# Out:
# wikidata_id    0
# First Name     0
# Last Name      0
# Hand           0
# Country        0
# Height         0
# dtype: int64

# %%
clean_players.to_csv('../web_data/clean_atp_players.csv')
clean_wta_players.to_csv('../web_data/clean_wta_players.csv')

# %%
clean_wta_players
# Out:
#           wikidata_id  First Name     Last Name Hand Country  Height
# player_id
# 113190           NOID       Bobby         Riggs    U     USA       0
# 200000           NOID  Desconegut  Desconegudez    U     UNK       0
# 200001        Q134720     Martina        Hingis    R     SUI     170
# 200002        Q239686     Mirjana         Lucic    R     CRO     181
# 200003         Q11682     Justine         Henin    R     BEL     167
# ...               ...         ...           ...  ...     ...     ...
# 270041           NOID       Emily          Dunn    U     NZL       0
# 270042           NOID      Serena      Rodricks    U     IND       0
# 270043           NOID        Isha        Mohite    U     IND       0
# 270044           NOID         Una         Misic    U     NZL       0
# 270045           NOID       Dorea        Morina    U     NZL       0
#
# [70036 rows x 6 columns]

# %%
clean_players[clean_players['wikidata_id']!='NOID'].value_counts().sum()
# Out:
# np.int64(4894)

# %%
clean_data[clean_data['tourney_date'].astype(str).str[:4] != clean_data['tourney_id'].str[:4]]
# Out:
#                   match_id tour_year tourney_id tourney_name surface  \
# match_id
# 1972-301289    1972-301289      1972   1972-301     Auckland   Grass
# 1972-301290    1972-301290      1972   1972-301     Auckland   Grass
# 1972-301291    1972-301291      1972   1972-301     Auckland   Grass
# 1972-301292    1972-301292      1972   1972-301     Auckland   Grass
# 1972-301293    1972-301293      1972   1972-301     Auckland   Grass
# ...                    ...       ...        ...          ...     ...
# 2019-M020272  2019-M020272      2019  2019-M020     Brisbane    Hard
# 2019-M020273  2019-M020273      2019  2019-M020     Brisbane    Hard
# 2019-M020275  2019-M020275      2019  2019-M020     Brisbane    Hard
# 2019-0451297  2019-0451297      2019  2019-0451         Doha    Hard
# 2019-M020276  2019-M020276      2019  2019-M020     Brisbane    Hard
#
#              tourney_level tourney_date  match_num              score  \
# match_id
# ...
